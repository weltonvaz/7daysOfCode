# %% [markdown]
# # **Processo conhecido como Data Wrangling**

# %% [markdown]
# Abrir um arquivo CSV no **Colab Research Google**, você pode seguir os seguintes passos:
#
# *Primeiro, faça o upload do arquivo CSV para o seu ambiente do Colab Research. Você pode fazer isso clicando no ícone "Arquivos" na barra lateral esquerda e, em seguida, clicando no botão "Fazer upload" na parte inferior do painel.
#
# Segundo, depois de fazer o upload do arquivo CSV, você pode carregá-lo em um DataFrame do Pandas usando o seguinte código:*

# %%
import pandas as pd
df = pd.read_csv('/content/despesa_ceaps_2022.csv',encoding="ISO-8859-1")

# %%
df.head()
# Out:
#     ANO  MES       SENADOR                                       TIPO_DESPESA  \
# 0  2022    1  ACIR GURGACZ  Aluguel de imóveis para escritório político, c...
# 1  2022    1  ACIR GURGACZ                Divulgação da atividade parlamentar
# 2  2022    1  ACIR GURGACZ                Divulgação da atividade parlamentar
# 3  2022    1  ACIR GURGACZ                Divulgação da atividade parlamentar
# 4  2022    1  ACIR GURGACZ                Divulgação da atividade parlamentar
#
#              CNPJ_CPF                                         FORNECEDOR  \
# 0      004.948.028-63                      GILBERTO PISELO DO NASCIMENTO
# 1  26.320.603/0001-64                                      INFORMANAHORA
# 2  13.659.201/0001-47                    LINHA PURPURA FOTO E VIDEO LTDA
# 3  23.652.846/0001-01                  ROBERTO GUTIERREZ DA ROCHA M.E.I.
# 4  08.941.827/0001-01  RONDONIA DINÂMICA COM. E SERV. DE INFORMÁTICA ...
#
#            DOCUMENTO        DATA  \
# 0             001/22  03/01/2022
# 1  000000000000310/A  04/01/2022
# 2                107  14/01/2022
# 3                187  18/01/2022
# 4  000000000001772/A  17/01/2022
#
#                                         DETALHAMENTO VALOR_REEMBOLSADO  \
# 0  Despesa com pagamento de aluguel de imóvel par...              6000
# 1  Despesa com divulgação da atividade parlamenta...              1500
# 2  Despesa com produção de texto e edição de víde...              6000
# 3                Divulgação da atividade parlamentar              1000
# 4                Divulgação da atividade parlamentar              2000
#
#    COD_DOCUMENTO
# 0        2173614
# 1        2173615
# 2        2173616
# 3        2173618
# 4        2173617

# %% [markdown]
# Verificando informação do dataset, arquivo: despesa_ceaps_2022.csv
# Com os comandos:
#
# ---
#
#
# <df.shape> = *Por exemplo, se você tiver um DataFrame chamado "df" com 100 linhas e 5 colunas, o comando "df.shape" retornará a tupla (100, 5).*
#
# <df.columns> = *O comando df.columns é usado para retornar os rótulos das colunas de um objeto DataFrame do Pandas. Ele retorna um objeto Index que contém os rótulos das colunas do DataFrame*

# %%
df.shape
# Out:
# (16718, 11)

# %%
df.columns
# Out:
# Index(['ANO', 'MES', 'SENADOR', 'TIPO_DESPESA', 'CNPJ_CPF', 'FORNECEDOR',
#        'DOCUMENTO', 'DATA', 'DETALHAMENTO', 'VALOR_REEMBOLSADO',
#        'COD_DOCUMENTO'],
#       dtype='object')

# %%
df['COD_DOCUMENTO'].nunique()
# Out:
# 16718

# %%
df.isnull().any(axis=1)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 16713    False
# 16714    False
# 16715    False
# 16716    False
# 16717    False
# Length: 16718, dtype: bool

# %%
linhas_com_nulos = df[df.isnull().any(axis=1)]
linhas_com_nulos
# Out:
#         ANO  MES            SENADOR  \
# 120    2022    1  ALESSANDRO VIEIRA
# 121    2022    1  ALESSANDRO VIEIRA
# 122    2022    1  ALESSANDRO VIEIRA
# 123    2022    1  ALESSANDRO VIEIRA
# 124    2022    1  ALESSANDRO VIEIRA
# ...     ...  ...                ...
# 16707  2022   12   ZEQUINHA MARINHO
# 16708  2022   12   ZEQUINHA MARINHO
# 16709  2022   12   ZEQUINHA MARINHO
# 16710  2022   12   ZEQUINHA MARINHO
# 16711  2022   12   ZEQUINHA MARINHO
#
#                                             TIPO_DESPESA            CNPJ_CPF  \
# 120    Aluguel de imóveis para escritório político, c...  28.839.939/0001-63
# 121    Aluguel de imóveis para escritório político, c...  06.028.059/0001-74
# 122    Aluguel de imóveis para escritório político, c...  40.432.544/0107-03
# 123    Aluguel de imóveis para escritório político, c...  13.017.462/0001-63
# 124    Aquisição de material de consumo para uso no e...  11.088.468/0001-04
# ...                                                  ...                 ...
# 16707  Locomoção, hospedagem, alimentação, combustíve...  19.614.800/0001-20
# 16708  Locomoção, hospedagem, alimentação, combustíve...  34.307.872/0001-19
# 16709  Locomoção, hospedagem, alimentação, combustíve...  09.631.455/0001-80
# 16710  Locomoção, hospedagem, alimentação, combustíve...  02.280.133/0042-62
# 16711  Locomoção, hospedagem, alimentação, combustíve...  28.298.039/0001-56
#
#                                               FORNECEDOR      DOCUMENTO  \
# 120    CASA DESIGN SERVICOS DE APOIO ADMINISTRATIVO LTDA           1253
# 121                      CASA SHOPPING DESING LTDA - EPP           1872
# 122                                      CLARO S.A / NET  2201905697962
# 123                                             ENERGISA       42551180
# 124                                KAFLEX COMERCIAL LTDA              1
# ...                                                  ...            ...
# 16707  AUTO POSTO INDEPENDENCIA COMERCIO DE COMBUSTÍV...         685963
# 16708               J M F COMÉRCIO DE COMBUSTIVEIS LTDA.          21169
# 16709    POSTO CAMILA VAREJISTA DE COMBUSTÍVEL LTDA. EPP        1446149
# 16710                                  POSTO ICCAR LTDA.         197440
# 16711                            REDE POSTO POMBAL LTDA.         221800
#
#              DATA DETALHAMENTO VALOR_REEMBOLSADO  COD_DOCUMENTO
# 120    04/01/2022          NaN               500        2175348
# 121    10/02/2022          NaN              3300        2175347
# 122    01/01/2022          NaN            235,96        2174131
# 123    13/01/2022          NaN            455,96        2174169
# 124    23/02/2022          NaN               800        2175349
# ...           ...          ...               ...            ...
# 16707  02/12/2022          NaN               200        2192243
# 16708  04/12/2022          NaN               300        2192248
# 16709  02/12/2022          NaN             352,5        2192242
# 16710  07/12/2022          NaN            200,03        2192250
# 16711  09/12/2022          NaN               200        2192249
#
# [8329 rows x 11 columns]

# %%
df.isnull().sum()
# Out:
# ANO                     0
# MES                     0
# SENADOR                 0
# TIPO_DESPESA            0
# CNPJ_CPF                0
# FORNECEDOR              0
# DOCUMENTO             933
# DATA                    0
# DETALHAMENTO         7663
# VALOR_REEMBOLSADO       0
# COD_DOCUMENTO           0
# dtype: int64

# %%
df['DOCUMENTO'].fillna('SEM COMPROVAÇÃO DE DOCUMENTO', inplace=True)

# %%
df['DETALHAMENTO'].fillna('SEM DETALHAMENTO DE DOCUMENTO', inplace=True)

# %%
df.isnull().sum()
# Out:
# ANO                  0
# MES                  0
# SENADOR              0
# TIPO_DESPESA         0
# CNPJ_CPF             0
# FORNECEDOR           0
# DOCUMENTO            0
# DATA                 0
# DETALHAMENTO         0
# VALOR_REEMBOLSADO    0
# COD_DOCUMENTO        0
# dtype: int64

# %%
dados_sem_comprovacao = df.loc[(df['DOCUMENTO'] == 'SEM COMPROVAÇÃO DE DOCUMENTO') & (df['DETALHAMENTO'] == 'SEM DETALHAMENTO DE DOCUMENTO')]
dados_sem_comprovacao
# Out:
#         ANO  MES             SENADOR  \
# 173    2022    3   ALESSANDRO VIEIRA
# 174    2022    3   ALESSANDRO VIEIRA
# 318    2022    2  ALEXANDRE SILVEIRA
# 319    2022    2  ALEXANDRE SILVEIRA
# 320    2022    2  ALEXANDRE SILVEIRA
# ...     ...  ...                 ...
# 16292  2022   10        ZENAIDE MAIA
# 16305  2022   11        ZENAIDE MAIA
# 16307  2022   11        ZENAIDE MAIA
# 16333  2022   12        ZENAIDE MAIA
# 16335  2022   12        ZENAIDE MAIA
#
#                                             TIPO_DESPESA            CNPJ_CPF  \
# 173    Locomoção, hospedagem, alimentação, combustíve...  17.630.688/0001-96
# 174    Locomoção, hospedagem, alimentação, combustíve...  17.630.688/0001-96
# 318    Aluguel de imóveis para escritório político, c...  10.589.016/0001-35
# 319    Aluguel de imóveis para escritório político, c...  10.589.016/0001-35
# 320    Aluguel de imóveis para escritório político, c...  18.715.383/0001-40
# ...                                                  ...                 ...
# 16292  Aluguel de imóveis para escritório político, c...      010.938.864-04
# 16305  Aluguel de imóveis para escritório político, c...  08.334.385/0001-35
# 16307  Aluguel de imóveis para escritório político, c...      010.938.864-04
# 16333  Aluguel de imóveis para escritório político, c...  08.334.385/0001-35
# 16335  Aluguel de imóveis para escritório político, c...      010.938.864-04
#
#                            FORNECEDOR                     DOCUMENTO  \
# 173            LOCADORA CB RENT A CAR  SEM COMPROVAÇÃO DE DOCUMENTO
# 174            LOCADORA CB RENT A CAR  SEM COMPROVAÇÃO DE DOCUMENTO
# 318    GREENWICH EMPREENDIMENTOS LTDA  SEM COMPROVAÇÃO DE DOCUMENTO
# 319    GREENWICH EMPREENDIMENTOS LTDA  SEM COMPROVAÇÃO DE DOCUMENTO
# 320                  PREFEITURA DE BH  SEM COMPROVAÇÃO DE DOCUMENTO
# ...                               ...                           ...
# 16292          João Mauricio de Sousa  SEM COMPROVAÇÃO DE DOCUMENTO
# 16305                           CAERN  SEM COMPROVAÇÃO DE DOCUMENTO
# 16307          João Mauricio de Sousa  SEM COMPROVAÇÃO DE DOCUMENTO
# 16333                           CAERN  SEM COMPROVAÇÃO DE DOCUMENTO
# 16335          João Mauricio de Sousa  SEM COMPROVAÇÃO DE DOCUMENTO
#
#              DATA                   DETALHAMENTO VALOR_REEMBOLSADO  \
# 173    10/03/2022  SEM DETALHAMENTO DE DOCUMENTO               270
# 174    30/03/2022  SEM DETALHAMENTO DE DOCUMENTO               270
# 318    05/02/2022  SEM DETALHAMENTO DE DOCUMENTO           2914,82
# 319    10/02/2022  SEM DETALHAMENTO DE DOCUMENTO              6300
# 320    01/02/2022  SEM DETALHAMENTO DE DOCUMENTO             489,4
# ...           ...                            ...               ...
# 16292  07/10/2022  SEM DETALHAMENTO DE DOCUMENTO              2300
# 16305  21/11/2022  SEM DETALHAMENTO DE DOCUMENTO             70,99
# 16307  07/11/2022  SEM DETALHAMENTO DE DOCUMENTO              2300
# 16333  23/12/2022  SEM DETALHAMENTO DE DOCUMENTO             70,99
# 16335  06/12/2022  SEM DETALHAMENTO DE DOCUMENTO              2300
#
#        COD_DOCUMENTO
# 173          2177596
# 174          2177597
# 318          2174617
# 319          2174619
# 320          2174615
# ...              ...
# 16292        2188001
# 16305        2190259
# 16307        2189418
# 16333        2192816
# 16335        2191111
#
# [267 rows x 11 columns]

# %%
numero_de_dados_sem_comprovacao = dados_sem_comprovacao.shape[0]

numero_de_dados_sem_comprovacao
# Out:
# 267

# %%
df.to_csv('/content/despesas_ceaps_2022_atualizado.csv', index=False)

# %%
df_atualizado = pd.read_csv('/content/despesas_ceaps_2022_atualizado.csv', encoding="ISO-8859-1")

# %%
df_atualizado.head()
# Out:
#     ANO  MES       SENADOR                                       TIPO_DESPESA  \
# 0  2022    1  ACIR GURGACZ  Aluguel de imÃ³veis para escritÃ³rio polÃ­tico...
# 1  2022    1  ACIR GURGACZ              DivulgaÃ§Ã£o da atividade parlamentar
# 2  2022    1  ACIR GURGACZ              DivulgaÃ§Ã£o da atividade parlamentar
# 3  2022    1  ACIR GURGACZ              DivulgaÃ§Ã£o da atividade parlamentar
# 4  2022    1  ACIR GURGACZ              DivulgaÃ§Ã£o da atividade parlamentar
#
#              CNPJ_CPF                                         FORNECEDOR  \
# 0      004.948.028-63                      GILBERTO PISELO DO NASCIMENTO
# 1  26.320.603/0001-64                                      INFORMANAHORA
# 2  13.659.201/0001-47                    LINHA PURPURA FOTO E VIDEO LTDA
# 3  23.652.846/0001-01                  ROBERTO GUTIERREZ DA ROCHA M.E.I.
# 4  08.941.827/0001-01  RONDONIA DINÃMICA COM. E SERV. DE INFORMÃTIC...
#
#            DOCUMENTO        DATA  \
# 0             001/22  03/01/2022
# 1  000000000000310/A  04/01/2022
# 2                107  14/01/2022
# 3                187  18/01/2022
# 4  000000000001772/A  17/01/2022
#
#                                         DETALHAMENTO VALOR_REEMBOLSADO  \
# 0  Despesa com pagamento de aluguel de imÃ³vel pa...              6000
# 1  Despesa com divulgaÃ§Ã£o da atividade parlamen...              1500
# 2  Despesa com produÃ§Ã£o de texto e ediÃ§Ã£o de ...              6000
# 3              DivulgaÃ§Ã£o da atividade parlamentar              1000
# 4              DivulgaÃ§Ã£o da atividade parlamentar              2000
#
#    COD_DOCUMENTO
# 0        2173614
# 1        2173615
# 2        2173616
# 3        2173618
# 4        2173617

# %%
df.isnull().isnull().sum()
# Out:
# ANO                  0
# MES                  0
# SENADOR              0
# TIPO_DESPESA         0
# CNPJ_CPF             0
# FORNECEDOR           0
# DOCUMENTO            0
# DATA                 0
# DETALHAMENTO         0
# VALOR_REEMBOLSADO    0
# COD_DOCUMENTO        0
# dtype: int64

# %%
dados_sem_comprovacao.to_csv('/content/despesa_ceaps_2022_sem_comprovacao.csv', columns=df.columns, index=False)

# %%
df_sem_comprovacao = pd.read_csv('/content/despesa_ceaps_2022_sem_comprovacao.csv', encoding="ISO-8859-1")
df_sem_comprovacao
# Out:
#       ANO  MES             SENADOR  \
# 0    2022    3   ALESSANDRO VIEIRA
# 1    2022    3   ALESSANDRO VIEIRA
# 2    2022    2  ALEXANDRE SILVEIRA
# 3    2022    2  ALEXANDRE SILVEIRA
# 4    2022    2  ALEXANDRE SILVEIRA
# ..    ...  ...                 ...
# 262  2022   10        ZENAIDE MAIA
# 263  2022   11        ZENAIDE MAIA
# 264  2022   11        ZENAIDE MAIA
# 265  2022   12        ZENAIDE MAIA
# 266  2022   12        ZENAIDE MAIA
#
#                                           TIPO_DESPESA            CNPJ_CPF  \
# 0    LocomoÃ§Ã£o, hospedagem, alimentaÃ§Ã£o, combus...  17.630.688/0001-96
# 1    LocomoÃ§Ã£o, hospedagem, alimentaÃ§Ã£o, combus...  17.630.688/0001-96
# 2    Aluguel de imÃ³veis para escritÃ³rio polÃ­tico...  10.589.016/0001-35
# 3    Aluguel de imÃ³veis para escritÃ³rio polÃ­tico...  10.589.016/0001-35
# 4    Aluguel de imÃ³veis para escritÃ³rio polÃ­tico...  18.715.383/0001-40
# ..                                                 ...                 ...
# 262  Aluguel de imÃ³veis para escritÃ³rio polÃ­tico...      010.938.864-04
# 263  Aluguel de imÃ³veis para escritÃ³rio polÃ­tico...  08.334.385/0001-35
# 264  Aluguel de imÃ³veis para escritÃ³rio polÃ­tico...      010.938.864-04
# 265  Aluguel de imÃ³veis para escritÃ³rio polÃ­tico...  08.334.385/0001-35
# 266  Aluguel de imÃ³veis para escritÃ³rio polÃ­tico...      010.938.864-04
#
#                          FORNECEDOR                       DOCUMENTO  \
# 0            LOCADORA CB RENT A CAR  SEM COMPROVAÃÃO DE DOCUMENTO
# 1            LOCADORA CB RENT A CAR  SEM COMPROVAÃÃO DE DOCUMENTO
# 2    GREENWICH EMPREENDIMENTOS LTDA  SEM COMPROVAÃÃO DE DOCUMENTO
# 3    GREENWICH EMPREENDIMENTOS LTDA  SEM COMPROVAÃÃO DE DOCUMENTO
# 4                  PREFEITURA DE BH  SEM COMPROVAÃÃO DE DOCUMENTO
# ..                              ...                             ...
# 262         JoÃ£o Mauricio de Sousa  SEM COMPROVAÃÃO DE DOCUMENTO
# 263                           CAERN  SEM COMPROVAÃÃO DE DOCUMENTO
# 264         JoÃ£o Mauricio de Sousa  SEM COMPROVAÃÃO DE DOCUMENTO
# 265                           CAERN  SEM COMPROVAÃÃO DE DOCUMENTO
# 266         JoÃ£o Mauricio de Sousa  SEM COMPROVAÃÃO DE DOCUMENTO
#
#            DATA                   DETALHAMENTO VALOR_REEMBOLSADO  \
# 0    10/03/2022  SEM DETALHAMENTO DE DOCUMENTO               270
# 1    30/03/2022  SEM DETALHAMENTO DE DOCUMENTO               270
# 2    05/02/2022  SEM DETALHAMENTO DE DOCUMENTO           2914,82
# 3    10/02/2022  SEM DETALHAMENTO DE DOCUMENTO              6300
# 4    01/02/2022  SEM DETALHAMENTO DE DOCUMENTO             489,4
# ..          ...                            ...               ...
# 262  07/10/2022  SEM DETALHAMENTO DE DOCUMENTO              2300
# 263  21/11/2022  SEM DETALHAMENTO DE DOCUMENTO             70,99
# 264  07/11/2022  SEM DETALHAMENTO DE DOCUMENTO              2300
# 265  23/12/2022  SEM DETALHAMENTO DE DOCUMENTO             70,99
# 266  06/12/2022  SEM DETALHAMENTO DE DOCUMENTO              2300
#
#      COD_DOCUMENTO
# 0          2177596
# 1          2177597
# 2          2174617
# 3          2174619
# 4          2174615
# ..             ...
# 262        2188001
# 263        2190259
# 264        2189418
# 265        2192816
# 266        2191111
#
# [267 rows x 11 columns]
